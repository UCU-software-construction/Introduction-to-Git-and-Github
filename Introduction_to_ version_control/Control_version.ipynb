# %% [markdown]
# Version Control systems-- Keepa track of changes and who made them enables us to merge changes from different sources

# %% [markdown]
# Also keeps track of all the changes when they were changed who changed what and at what time they were made

# %%
Introduction to git 
Begining concepts-- 
A commit is an edit submitted to a vcs 
A repository is a centralized place developers keep code for a project inside a vcs that can be accessed by multiple people and edited if given the permission  too

# %%
Git config-- we can set emails and usernames so git knows who made what changes 
->git config --global user.email "itungoagaba@gmail.com"
->git config--global user.name "itungoagaba"

GIT directories (also as the database)
To make a new repository we can use git innit or we can use git clone to use an existing repository already 
From CLI--
We create a directory - mkdir directoryname 
We move to that directory - cd directoryname
we create a new repository- git init
we can track the changes in that repository through using - ls -l .git/

# %% [markdown]
# The working tree
# Once we create the new files in the working tree we add them to them to be tracked by using the commad git add
# We can also use git status to infomation about the current working tree and pending changes
# We then run the git commit command to save our changes.
